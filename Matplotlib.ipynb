# %% [markdown]
# # Matplotlib
# - Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# - It is numerical mathematics extention of numpy

# %%
# Import Matplotlib
import matplotlib

# %% [markdown]
# # Pyplot
# - Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %% [markdown]
# # ploting using matplotlib
# ## Scatter plot

# %%
plt.scatter(x,y,c="r")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Graph in 2D")
plt.show()

# %%
# for saving the plot
plt.savefig("test.png")

# %%
y=x*x
#plt plot
# %matplotlib inline
plt.plot(x,y)

# %%
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*--')

# %%
plt.plot(x,y,'r--',linewidth=2,markersize=2)

# %%
# creating subplot
plt.subplot(2,2,1)
plt.plot(x,y,"r")
plt.subplot(2,2,2)
plt.plot(x,y,"g")
plt.subplot(2,2,3)
plt.plot(x,y,"y")

# %%
x=np.arange(1,11)
y=3 * x+ 4
plt.xlabel("xaxis")
plt.ylabel("y axis")
plt.title("graphs")
plt.plot(x,y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.arange(0,4*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)

# %%
x=np.arange(0,4*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)
plt.subplot(2,1,1)
plt.plot(x,y_sin,'r--')
plt.subplot(2,1,2)
plt.plot(x,y_cos,"g--")

# %%
# bar plot
x=[1,2,3,4]
y=[3,5,6,2]


x2=[3,15,5,2]
y2=[6,7,9,10]

plt.bar(x,y)
plt.bar(x2,y2,color="g")
plt.show()

# %%
#histogram
a=np.array([20,10,2,3,5,15,7,5,3,21,22])
plt.hist(a)
plt.show()

# %%
a=np.array([20,10,2,3,5,15,7,5,3,21,22])
plt.hist((a),bins=20)
plt.show()

# %%
# boxplot
data=[np.random.normal(0,std,100) for std in range (1,4)]
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22ab39f3648>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22ab39f3fc8>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x22ab39ecf88>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x22ab39f8fc8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x22ab39fcfc8>,
# ...
#  'means': []}

# %%
data
# Out:
# [array([-0.59991797,  1.6163455 ,  0.21496235,  1.34809481, -1.03927992,
#         -1.15200155,  0.49979202,  0.75627831, -1.01858516, -1.07897927,
#          0.56520804,  1.05378411,  0.64374033, -1.30711122, -1.31222932,
#          0.03896622,  0.33812901,  1.10938981,  0.0089552 , -0.24024774,
#          0.75007983,  0.99807357,  1.6781437 , -1.14991242,  1.12802972,
#          0.87214297, -0.83301211, -0.42695305, -1.60491829, -1.44070466,
#          1.67195277,  0.52700194, -1.03185706,  0.16465731,  0.8789274 ,
#          0.10915109,  1.28945687, -0.07846912, -0.60830946,  0.48985437,
#          0.15610896,  1.15321188,  2.02728636, -0.81448094, -1.16241542,
#          0.45486981, -1.29042085,  0.56392401,  0.02896412, -0.3799063 ,
#          2.0631032 , -1.39163747, -0.37315625, -1.88370104,  0.38233103,
#          2.25794992,  1.14237446,  1.14351698, -0.90558329, -0.07789504,
#          0.690528  , -0.53226902, -1.3118472 ,  0.53511186,  0.21740881,
# ...

# %%
# pie chart
labels="python","c+","Ruby","Java"
size=[215,210,310,115]
colors=["red","green","lightblue","yellow"]
explode=(0.4,0,0,0)

plt.pie(size,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x22ab24a0a48>,
# ...
#  [Text(1.0508145068697083, 1.0704152802310754, 'python'),
#   Text(-0.784971241577051, 0.7705972682906312, 'c+'),
#   Text(-0.4535918300074524, -1.0021249681304676, 'Ruby'),
#   Text(1.0021249893646322, -0.45359178309459697, 'Java')],
#  [Text(0.7005430045798056, 0.7136101868207169, '25.3%'),
#   Text(-0.4281661317693005, 0.42032578270398063, '24.7%'),
#   Text(-0.24741372545861035, -0.546613618980255, '36.5%'),
#   Text(0.5466136305625267, -0.24741369986978012, '13.5%')])
